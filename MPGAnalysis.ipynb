# %% [markdown]
# ## Using k-means, Determine how cars are grouped together by using the mpg dataset in Seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load in Data

# %%
Mpg = sns.load_dataset('mpg')

# %%
Mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Data Wrangling

# %%
mpgTrimmed = Mpg.drop(['origin', 'name'], axis = 1)

# %%
mpgTrimmed.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model_year
# 0  18.0          8         307.0       130.0    3504          12.0          70
# 1  15.0          8         350.0       165.0    3693          11.5          70
# 2  18.0          8         318.0       150.0    3436          11.0          70
# 3  16.0          8         304.0       150.0    3433          12.0          70
# 4  17.0          8         302.0       140.0    3449          10.5          70

# %%
mpgTrimmed.dropna(inplace=True)

# %% [markdown]
# ### I had to come back and drop NA values after a warning when running the k-means

# %% [markdown]
# ## k-Means Analysis

# %%
kmeans = KMeans(n_clusters=2, n_init=10)
kmeans.fit(mpgTrimmed)
# Out:
# KMeans(n_clusters=2, n_init=10)

# %% [markdown]
# ## Graphing

# %% [markdown]
# ## First with 2 clusters (high and low)

# %% [markdown]
# ### MPG & Cylinders

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['cylinders'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Cylinders')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Weight

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['weight'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Weight')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Horsepower

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['horsepower'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Displacement

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['displacement'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Displacement')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Acceleration

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['acceleration'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Acceleration')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Model Year

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['model_year'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Model Year')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### Next trying 3 clusters (high, medium, and low)

# %%
kmeans = KMeans(n_clusters=3, n_init=10)
kmeans.fit(mpgTrimmed)
# Out:
# KMeans(n_clusters=3, n_init=10)

# %% [markdown]
# ### MPG & Cylinders

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['cylinders'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Cylinders')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Weight

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['weight'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Weight')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Horsepower

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['horsepower'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ### MPG & Displacement

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['displacement'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Displacement')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ## MPG & Acceleration

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['acceleration'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Acceleration')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ## MPG & Model Year

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['model_year'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Model Year')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
kmeans = KMeans(n_clusters=4, n_init=10)
kmeans.fit(mpgTrimmed)
# Out:
# KMeans(n_clusters=4, n_init=10)

# %%
plt.figure(figsize=(10,6))
plt.title('K Means')
plt.scatter(mpgTrimmed['weight'], mpgTrimmed['mpg'], c=kmeans.labels_, cmap='cividis')
plt.xlabel('Weight')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# ## This one example of 4 clusters shows that this many clusters is a bit cluttered. I like 3.

# %%
mpgTrimmed['Group'] = kmeans.labels_

# %%
mpgTrimmed.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  Group
# 0          70      0
# 1          70      2
# 2          70      0
# 3          70      0
# 4          70      0

# %%
kmeans.cluster_centers_
# Out:
# array([[2.07893443e+01, 5.81967213e+00, 2.12614754e+02, 1.05401639e+02,
#         3.16258197e+03, 1.59040984e+01, 7.63524590e+01],
#        [2.96516667e+01, 4.03888889e+00, 1.07208333e+02, 7.71666667e+01,
#         2.22282778e+03, 1.63344444e+01, 7.67111111e+01],
#        [1.46355556e+01, 7.86666667e+00, 3.44144444e+02, 1.57811111e+02,
#         4.23632222e+03, 1.34633333e+01, 7.40111111e+01]])

# %%
kmeans.inertia_
# Out:
# 33849027.585479066

# %% [markdown]
# ## Means by Category

# %%
mpgTrimmed.groupby('Group')['mpg'].mean()
# Out:
# Group
# 0    20.789344
# 1    29.651667
# 2    14.635556
# Name: mpg, dtype: float64

# %%
mpgTrimmed.groupby('Group')['cylinders'].mean()
# Out:
# Group
# 0    5.819672
# 1    4.038889
# 2    7.866667
# Name: cylinders, dtype: float64

# %%
mpgTrimmed.groupby('Group')['displacement'].mean()
# Out:
# Group
# 0    212.614754
# 1    107.208333
# 2    344.144444
# Name: displacement, dtype: float64

# %%
mpgTrimmed.groupby('Group')['horsepower'].mean()
# Out:
# Group
# 0    105.401639
# 1     77.166667
# 2    157.811111
# Name: horsepower, dtype: float64

# %%
mpgTrimmed.groupby('Group')['weight'].mean()
# Out:
# Group
# 0    3162.581967
# 1    2222.827778
# 2    4236.322222
# Name: weight, dtype: float64

# %%
mpgTrimmed.groupby('Group')['acceleration'].mean()
# Out:
# Group
# 0    15.904098
# 1    16.334444
# 2    13.463333
# Name: acceleration, dtype: float64

# %%
mpgTrimmed.groupby('Group')['model_year'].mean()
# Out:
# Group
# 0    76.352459
# 1    76.711111
# 2    74.011111
# Name: model_year, dtype: float64

# %% [markdown]
# ## Group analysis

# %% [markdown]
# ## Group 0:
# ### 20.8 mpg, 5.8 cyl, 212.6 displacement, 105 hp, 3163 wt, 15.9 accel, 76.35 yr
# ## Group 1:
# ### 29.7 mpg, 4.0 cyl, 107.2 displacement, 77 hp, 2223 wt, 16.3 accel, 76.7 yr
# ## Group 2:
# ### 14.6 mpg, 7.9 cyl, 344.1 displacement, 157.8 hp, 4236 wt, 14.5 accel, 74.0 yr

# %% [markdown]
# ## Group 2 is our low mpg group. Generally more cylinders, higher displacement, higher horsepower, heavier, and faster acceleration. These seem to be the oldest cars tested.

# %% [markdown]
# ## Group 0 is the middle mpg group. All values fit between the other two groups. These cars on average are just slightly older than the "best" group.

# %% [markdown]
# ## Group 1 is high mpg group. Fewer cylinders, lower displacement, horsepower, and weight, with slower acceleration rates. These generally tend to be the newest cars.

# %% [markdown]
# ## This process can be repeated to compare any of the variables to the others.
